# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
import math
from mpl_toolkits import mplot3d

# %%
x = [1, 3, 2, 5]
x
# Out:
# [1, 3, 2, 5]

# %%
x = [1, 6, 2]
y = [1, 4, 3]
sum_list = []
len(x)
for i in range(len(x)): sum_list.append(x[i] + y[i])
print(sum_list)
# Out:
# [2, 10, 5]

# %%
locals()
# Out:
# 761           9.5    70
#   13   14.0          8         455.0       225.0    3086          10.0    70
#   14   24.0          4         113.0        95.0    2372          15.0    70
#   15   22.0          6         198.0        95.0    2833          15.5    70
#   16   18.0          6         199.0        97.0    2774          15.5    70
#   17   21.0          6         200.0        85.0    2587          16.0    70
#   18   27.0          4          97.0        88.0    2130          14.5    70
#   19   26.0          4          97.0        46.0    1835          20.5    70
#   20   25.0          4         110.0        87.0    2672          17.5    70
#   21   24.0          4         107.0        90.0    2430          14.5    70
#   22   25.0          4         104.0        95.0    2375          17.5    70
#   23   26.0          4         121.0       113.0    2234          12.5    70
#   24   21.0          6         199.0        90.0    2648          15.0    70
# ...

# %%
X = [[1, 2], [3, 4]]
print(X)
Y = np.array([[1,2], [3,4]])
print(Y)
# Out:
# [[1, 2], [3, 4]]
# [[1 2]
#  [3 4]]

# %%
np.sqrt(X)
# Out:
# array([[ 1.        ,  1.41421356],
#        [ 1.73205081,  2.        ]])

# %%
A = np.random.standard_normal(50)
B = np.random.normal(50, .1, 50)
print(A)
plt.plot(A)
plt.show()
# Out:
# [ 0.16222419  1.96136588 -0.33911615 -0.63355255 -0.10782634 -0.94371892
#  -0.74674153  0.78694034 -0.35067873 -1.25222389  1.47411036  1.30007928
#   1.37126343  0.56998228  0.36657313  0.04945607  2.59079192 -3.15289311
#   0.1193166  -1.39185914 -1.18244034 -1.56501765  0.48124656 -1.91096787
#   0.76978117 -0.40601026  0.43223767  0.18662365  0.09649847 -0.59766473
#   1.49566538 -0.54229446  1.12676617 -0.59438406  0.75397616  1.28216297
#   0.28192735 -0.55185184  0.41946019 -0.91703132  1.38219084  0.79057186
#  -0.55735253  0.32702488 -0.8395961  -1.72391802  0.02687637 -0.54402368
#  -1.01600331  0.59409609]

# %%
data = {'A': A, 'B': B}
# data = A.B
df = pd.DataFrame(data, columns=['A', 'B'])
corrMatrix = df.corr()
print(corrMatrix)
print(corrMatrix.loc['A', 'B'])
# Out:
# A        B
# A  1.00000 -0.10213
# B -0.10213  1.00000
# -0.102130336454

# %%
data2 = np.corrcoef(A, B)
print data2
# Out:
# [[ 1.         -0.10213034]
#  [-0.10213034  1.        ]]

# %%
sn.heatmap(corrMatrix, annot=True)
plt.savefig('Chapter 2/figure.2.jpg')
plt.show()

# %%
np.random.seed(5)
C = np.random.standard_normal(100)
print np.mean(C)
print np.var(C)
print np.sqrt(np.var(C))
print np.std(C)
# Out:
# 0.0915466438678
# 0.86671762193
# 0.930976703216
# 0.930976703216

# %%
X = np.random.standard_normal(100)
Y = np.random.standard_normal(100)
plt.scatter(X, Y, s=30, c='red')
plt.legend(["test"])
plt.xlabel("This is the x axis")
plt.ylabel("This is the y axis")
plt.title("This is X vs Y")
plt.savefig("python_figure_1.jpg")
plt.savefig('Chapter 2/figure.3.jpg')
plt.show()

# %%
# x = range(1, 11)
x = np.linspace(-math.pi, math.pi, 50)
print x
print x.size
print len(x)
y=x
f = np.outer(np.cos(y),1/(1+(x**2)))
print f.size
plt.contour(x,y,f)
plt.savefig('Chapter 2/figure.4.jpg')
plt.show();
# Out:
# [-3.14159265 -3.01336438 -2.88513611 -2.75690784 -2.62867957 -2.5004513
#  -2.37222302 -2.24399475 -2.11576648 -1.98753821 -1.85930994 -1.73108167
#  -1.60285339 -1.47462512 -1.34639685 -1.21816858 -1.08994031 -0.96171204
#  -0.83348377 -0.70525549 -0.57702722 -0.44879895 -0.32057068 -0.19234241
#  -0.06411414  0.06411414  0.19234241  0.32057068  0.44879895  0.57702722
#   0.70525549  0.83348377  0.96171204  1.08994031  1.21816858  1.34639685
#   1.47462512  1.60285339  1.73108167  1.85930994  1.98753821  2.11576648
#   2.24399475  2.37222302  2.5004513   2.62867957  2.75690784  2.88513611
#   3.01336438  3.14159265]
# 50
# 50
# 2500

# %%
plt.contour(x, y, f, levels=[.1, .2, .3, .4, .5])
plt.show()

# %%
# g = np.outer(np.cos(y),1/(1+(x**2))).t
fa = np.subtract(f, f.transpose())/2
print fa.size
plt.contour(x, y, fa)
plt.savefig('Chapter 2/figure.5.jpg')
plt.show();
# Out:
# 2500

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)

ax.contour3D(X, Y, fa, 100, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
plt.savefig('Chapter 2/figure.6.jpg')
ax.view_init(60, 35)
plt.savefig('Chapter 2/figure.7.jpg')
fig
plt.show();

# %%
A = np.arange(1, 17, 1).reshape(4,4).transpose()
print A
# Out:
# [[ 1  5  9 13]
#  [ 2  6 10 14]
#  [ 3  7 11 15]
#  [ 4  8 12 16]]

# %%
print A[[[0],[2]], [1,3]]
# Out:
# [[ 5 13]
#  [ 7 15]]

# %%
print A[0:3:1, 1:4:1]
# Out:
# [[ 5  9 13]
#  [ 6 10 14]
#  [ 7 11 15]]

# %%
print A[0:2,:]
# Out:
# [[ 1  5  9 13]
#  [ 2  6 10 14]]

# %%
print A[:, 0:2]
# Out:
# [[1 5]
#  [2 6]
#  [3 7]
#  [4 8]]

# %%
print A[0,:]
# Out:
# [ 1  5  9 13]

# %%
print A[-1, -1]
# Out:
# 16

# %%
print os.getcwd()
data = pd.read_csv("../Auto.csv", header=0, na_values='?')
data.head()
# print data.__sizeof__
data = data.dropna()
print data.shape
# Out:
# c:\Users\j3kk\Machine-Learning\ISL Python
# (392, 9)

# %%
plt.plot(data.cylinders, data.mpg, 'ro')
plt.savefig('Chapter 2/figure.8.jpg')
plt.show();

# %%
data.hist(column=['cylinders', 'mpg'])
plt.savefig('Chapter 2/figure.9.jpg')
plt.show();

# %%
data.describe
# Out:
# <bound method DataFrame.describe of       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# 5    15.0          8         429.0       198.0    4341          10.0    70
# 6    14.0          8         454.0       220.0    4354           9.0    70
# 7    14.0          8         440.0       215.0    4312           8.5    70
# 8    14.0          8         455.0       225.0    4425          10.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 10   15.0          8         383.0       170.0    3563          10.0    70
# ...

# %%
data.describe(include='all')
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   392.000000  392.000000    392.000000  392.000000   392.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.445918    5.471939    194.411990  104.469388  2977.584184
# std       7.805007    1.705783    104.644004   38.491160   849.402560
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%      22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%      29.000000    8.000000    275.750000  126.000000  3614.750000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration        year      origin        name
# count     392.000000  392.000000  392.000000         392
# ...
