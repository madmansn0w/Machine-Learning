# %%
import numpy as np                  # linear algebra
import matplotlib.pyplot as plt
import h5py                         # for processing the hdfs datasets
import glob

# %%
ligoDataPaths = glob.glob(".\datasets\*.hdf5")
print ligoDataPaths
# Out:
# ['.\\datasets\\H-H1_LOSC_16_V1-1126259446-32.hdf5', '.\\datasets\\H-H1_LOSC_4_V1-1126259446-32.hdf5', '.\\datasets\\L-L1_LOSC_16_V1-1126259446-32.hdf5', '.\\datasets\\L-L1_LOSC_4_V1-1126259446-32.hdf5']

# %%
sample = str(ligoDataPaths[0])
print sample
sample.stype
f = h5py.File(sample, 'r')
f.name

# for item in f.attrs.keys():
#     print item + ":", f.attrs[item]
f.close()
# meta = f['meta']
# quality = f['quality']
# strain = f['strain']
# print "%s\t%s\t%s" % ("meta", "quality", "strain")
# for i in range(len(meta)):
#     print "%s\t\%s\t%s" % (meta[i], quality[i], strain[i])
# f.close()
# Out:
# .\datasets\H-H1_LOSC_16_V1-1126259446-32.hdf5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-0c3ca4098a76> in <module>()
#       1 sample = str(ligoDataPaths[0])
#       2 print sample
# ----> 3 sample.stype
#       4 f = h5py.File(sample, 'r')
#       5 f.name
#
# AttributeError: 'str' object has no attribute 'stype'

# %%
for fname in ligoDataPaths:
    objSets = h5py.File(fname,'r')
    strain = list(objSets['strain'].values())[0]
for key in objSets.keys():
    print key
print objSets[0]
# timeSpacing = list(strain['strain']['Strain'].attrs['Xspacing'])
# Out:
# meta
# quality
# strain
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-817fb55c8adb> in <module>()
#       4 for key in objSets.keys():
#       5     print key
# ----> 6 print objSets[0]
#       7 # timeSpacing = list(strain['strain']['Strain'].attrs['Xspacing'])
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper (C:\Minonda\conda-bld\h5py_1490029245709\work\h5py\_objects.c:2867)()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper (C:\Minonda\conda-bld\h5py_1490029245709\work\h5py\_objects.c:2825)()
#
# C:\Users\j3kk\Anaconda2\lib\site-packages\h5py\_hl\group.pyc in __getitem__(self, name)
#     167                 raise ValueError("Invalid HDF5 object reference")
#     168         else:
# --> 169             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     170
#     171         otype = h5i.get_type(oid)
#
# C:\Users\j3kk\Anaconda2\lib\site-packages\h5py\_hl\base.pyc in _e(self, name, lcpl)
#     131         else:
#     132             try:
# --> 133                 name = name.encode('ascii')
#     134                 coding = h5t.CSET_ASCII
#     135             except UnicodeEncodeError:
#
# AttributeError: 'int' object has no attribute 'encode'

# %%
plt.figure(figsize = (14, 6))
i = 0
col = ['r', 'g', 'b', 'k']
for fname in ligodatapath:
    d = h5py.File(path.join(dirpath, fname), "r")
    strain = list(d['strain'].values())[0]
    plt.plot(strain[...], color= col[i], label = fname, markersize = 1)
    i += 1
    d.close()
plt.legend()
plt.show()
## more timeseries work needed to mathc events with time stamps
# %%
